# %% [markdown]
# # Reconocimiento de vocales

# %% [markdown]
# ## Estandarización del formato de los audios capturados a `.wav`.
#
# Por defecto:
# * Whatsapp: `*.ogg`
# * Grabadora de voz win10: `*.m4a`

# %%
# Para correr en google colab

from google.colab import drive
import sys
import os

# Conecta drive a colab
drive.mount('/content/drive')
sys.path.insert(0, '/content/drive/MyDrive/Education/urosario/github/macc/machine learning/Proyecto 2 - reconocimiento vocales NN')

# asigna la ruta de trabajo del proyecto dentro del drive
os.chdir('/content/drive/MyDrive/Education/urosario/github/macc/machine learning/Proyecto 2 - reconocimiento vocales NN')

# %%
# importa librerias y define rutas
import os 
import glob
import librosa
import soundfile 

CURRENT_PATH = os.getcwd()
SAMPLES_PATH = os.path.join(CURRENT_PATH, os.path.pardir, 'database')

# %%
# Transforma todos los audios a formato .wav

import warnings
warnings.filterwarnings("ignore")

for format in ['ogg', 'm4a']:
    for vowel in ['a', 'e', 'i', 'o', 'u']:
        # absolute path to search all text files inside a specific folder
        path = os.path.join(SAMPLES_PATH, f'{vowel}', f'*.{format}')
        #print(path)
        files = glob.glob(path)
        #print(files)
        i = 1
        for file in files:
          print("in for cycle for change format")
          audio, sr = librosa.load(str(file), sr = 16000)
          #soundfile.write("test file.wav", audio ,16000)
          soundfile.write(os.path.join(SAMPLES_PATH, f'{vowel}', f'{vowel}t_({i}).wav'), audio ,16000)
          i+=1            

          if os.path.exists(file):
            print(f"file {file} deleted!")
            os.remove(file)

# %% [markdown]
# ## Cargando un archivo de audio

# %%
import librosa

audio_path = os.path.join(SAMPLES_PATH, 'a', 'a_(56).wav')
audio, sr = librosa.load(audio_path, sr = 16000)

# %% [markdown]
# ## Reproduciendo el audio

# %%
import IPython.display as ipd

ipd.Audio(audio_path) # no se puede reproducir en vscode :/
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Visualizando el audio

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import librosa.display

plt.figure(figsize=(14, 5))
librosa.display.waveshow(audio, sr=sr) # cambiar waveplot por waveshow, para librosa>=0.9

# %% [markdown]
# ## Generando el espectograma

# %%
X = librosa.stft(audio)
Xdb = librosa.amplitude_to_db(abs(X))
plt.figure(figsize=(14, 5))
librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')
plt.colorbar()

# %%
import numpy as np
list_test =[]
for e in Xdb:
        list_test.append(f' {e}')

list_test.sort(reverse=True)
Xdb[0]
# Out:
# array([ -1.2652242,  -5.6439066, -21.740892 , -35.38275  , -35.29714  ,
#        -38.10696  , -35.576443 , -36.81236  , -33.874603 , -42.78389  ,
#        -36.16855  , -33.447327 , -34.592396 , -42.218777 , -38.58451  ,
#        -37.29972  , -34.211437 , -38.32758  , -39.099365 , -37.576557 ,
#        -31.811096 , -11.542643 ,  -7.172797 ,  -9.322401 ,  -7.7629137,
#         -4.338761 ], dtype=float32)

# %%
sr
# Out:
# 16000

# %% [markdown]
# # Extracción de propiedades del audio

# %% [markdown]
# ## Centroide espectral

# %%
import sklearn
spectral_centroids = librosa.feature.spectral_centroid(audio, sr=sr)[0]
spectral_centroids.shape
#(775,)

# Computing the time variable for visualization
plt.figure(figsize=(12, 4))
frames = range(len(spectral_centroids))
t = librosa.frames_to_time(frames)

# Normalising the spectral centroid for visualisation
def normalize(audio, axis=0):
    return sklearn.preprocessing.minmax_scale(audio, axis=axis)

#Plotting the Spectral Centroid along the waveform
librosa.display.waveshow(audio, sr=sr, alpha=0.4) # cambiar waveplot por waveshow
plt.plot(t, normalize(spectral_centroids), color='b')

# %% [markdown]
# ## Spectral rolloff

# %%
spectral_rolloff = librosa.feature.spectral_rolloff(audio+0.01, sr=sr)[0]
plt.figure(figsize=(12, 4))

librosa.display.waveshow(audio, sr=sr, alpha=0.4) # waveshow
plt.plot(t, normalize(spectral_rolloff), color='r')

# %% [markdown]
# ## Ancho de banda espectral

# %%
spectral_bandwidth_2 = librosa.feature.spectral_bandwidth(audio+0.01, sr=sr)[0]
spectral_bandwidth_3 = librosa.feature.spectral_bandwidth(audio+0.01, sr=sr, p=3)[0]
spectral_bandwidth_4 = librosa.feature.spectral_bandwidth(audio+0.01, sr=sr, p=4)[0]
plt.figure(figsize=(15, 9))

librosa.display.waveshow(audio, sr=sr, alpha=0.4)
plt.plot(t, normalize(spectral_bandwidth_2), color='r')
plt.plot(t, normalize(spectral_bandwidth_3), color='g')
plt.plot(t, normalize(spectral_bandwidth_4), color='y')
plt.legend(('p = 2', 'p = 3', 'p = 4'))

# %% [markdown]
# ## Zero-Crossing Rate

# %%
#Plot the signal:
plt.figure(figsize=(14, 5))
librosa.display.waveshow(audio, sr=sr)
# Zooming in
n0 = 9000
n1 = 9100
plt.figure(figsize=(14, 5))
plt.plot(audio[n0:n1])
plt.grid()

# %% [markdown]
# ## Mel-Frequency Cepstral Coefficients(MFCCs)

# %%
mfccs = librosa.feature.mfcc(audio, sr=sr)
print(mfccs.shape)
#(20, 97)
#Displaying  the MFCCs:
plt.figure(figsize=(15, 7))
librosa.display.specshow(mfccs, sr=sr, x_axis='time')
plt.colorbar()
# Out:
# (20, 26)

# %%
import numpy as np
for e in mfccs:
        print(f' {np.mean(e)}')
# Out:
#  -233.50917053222656
#  153.91131591796875
#  -51.27812194824219
#  4.560914039611816
#  -14.107441902160645
#  -1.604628324508667
#  -21.648212432861328
#  -0.5536870360374451
#  -8.86152458190918
#  -15.779458999633789
#  -11.751972198486328
#  -15.318741798400879
#  -20.131032943725586
#  1.103346824645996
#  -11.98997688293457
#  -4.696319580078125
#  -6.7697834968566895
#  -9.47214412689209
#  -10.443201065063477
#  -3.848346710205078

# %% [markdown]
# ## Chroma feature

# %%
chromagram = librosa.feature.chroma_stft(audio, sr=sr, hop_length=512) # hop_lengt 512 según ejemplo
plt.figure(figsize=(15, 5))
librosa.display.specshow(chromagram, x_axis='time', y_axis='chroma', hop_length=512, cmap='coolwarm')

# %% [markdown]
# # Clasificación de audio usando ANN

# %% [markdown]
# First of all, we need to convert the audio files into PNG format images(spectrograms). From these spectrograms, we have to extract meaningful features, i.e. MFCCs, Spectral Centroid, Zero Crossing Rate, Chroma Frequencies, Spectral Roll-off. Once the features have been extracted, they can be appended into a CSV file so that ANN can be used for classification. If we wanna work with image data instead of CSV we will use CNN.
#
# So let's begin.

# %%
import librosa
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import os
from PIL import Image
import pathlib
import csv
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
import keras
from keras import layers
from keras import layers
import keras
from keras.models import Sequential
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Transformar audios en espectogramas (png)

# %%
IMAGES_PATH = os.path.join(CURRENT_PATH, os.path.pardir, 'images')

cmap = plt.get_cmap('inferno')
plt.figure(figsize=(8,8))
vowels = 'a e i o u'.split()
for vowel in vowels:
    for filename in os.listdir(os.path.join(SAMPLES_PATH, f'{vowel}'))[1:]: # debe empeza desde index 1 para no tener en cuenta la carpeta checkpoints 
        vowel_sample = os.path.join(SAMPLES_PATH, f'{vowel}', filename)
        if filename == 'desktop.ini': # omite desktop.ini
            break
        #print(filename)
        sample, sr = librosa.load(vowel_sample, mono=True, duration=5)
        plt.specgram(sample, NFFT=2048, Fs=2, Fc=0, noverlap=128, cmap=cmap, sides='default', mode='default', scale='dB')
        plt.axis('off')
        plt.savefig(os.path.join(IMAGES_PATH, f'{vowel}', f'{filename[:-3].replace(".", "")}.png')) # plt.savefig(f'img_data/{g}/{filename[:-3].replace(".", "")}.png')
        plt.clf()
# Out:
# a_(1).wav
# a_(10).wav
# a_(100).wav
# a_(101).wav
# a_(102).wav
# a_(103).wav
# a_(104).wav
# a_(105).wav
# a_(106).wav
# a_(107).wav
# a_(108).wav
# a_(109).wav
# a_(11).wav
# a_(110).wav
# a_(111).wav
# a_(112).wav
# a_(113).wav
# a_(114).wav
# a_(115).wav
# a_(116).wav
# a_(117).wav
# a_(118).wav
# a_(119).wav
# a_(12).wav
# a_(120).wav
# a_(121).wav
# a_(122).wav
# a_(123).wav
# a_(124).wav
# a_(125).wav
# a_(126).wav
# a_(127).wav
# a_(128).wav
# a_(129).wav
# a_(13).wav
# a_(130).wav
# a_(131).wav
# a_(132).wav
# a_(133).wav
# a_(134).wav
# a_(135).wav
# a_(136).wav
# a_(137).wav
# a_(138).wav
# a_(139).wav
# a_(14).wav
# a_(140).wav
# a_(141).wav
# a_(142).wav
# a_(143).wav
# a_(144).wav
# a_(145).wav
# a_(146).wav
# a_(147).wav
# a_(148).wav
# a_(149).wav
# a_(15).wav
# a_(150).wav
# a_(151).wav
# a_(152).wav
# a_(153).wav
# a_(154).wav
# a_(155).wav
# a_(156).wav
# a_(157).wav
# a_(158).wav
# a_(159).wav
# a_(16).wav
# a_(160).wav
# a_(161).wav
# a_(162).wav
# a_(163).wav
# a_(164).wav
# a_(165).wav
# a_(166).wav
# a_(167).wav
# a_(168).wav
# a_(169).wav
# a_(17).wav
# a_(170).wav
# a_(171).wav
# a_(172).wav
# a_(173).wav
# a_(174).wav
# a_(175).wav
# a_(176).wav
# a_(177).wav
# a_(178).wav
# a_(179).wav
# a_(18).wav
# a_(180).wav
# a_(181).wav
# a_(182).wav
# a_(183).wav
# a_(184).wav
# a_(185).wav
# a_(186).wav
# a_(187).wav
# a_(188).wav
# a_(189).wav
# a_(19).wav
# a_(190).wav
# a_(191).wav
# a_(192).wav
# a_(193).wav
# a_(194).wav
# a_(195).wav
# a_(196).wav
# a_(197).wav
# a_(198).wav
# a_(199).wav
# a_(2).wav
# a_(20).wav
# a_(200).wav
# a_(201).wav
# a_(202).wav
# a_(203).wav
# a_(204).wav
# a_(205).wav
# a_(206).wav
# a_(207).wav
# a_(208).wav
# a_(209).wav
# a_(21).wav
# a_(210).wav
# a_(211).wav
# a_(212).wav
# a_(213).wav
# a_(214).wav
# a_(215).wav
# a_(216).wav
# a_(217).wav
# a_(218).wav
# a_(219).wav
# a_(22).wav
# a_(220).wav
# a_(221).wav
# a_(222).wav
# a_(223).wav
# a_(224).wav
# a_(225).wav
# a_(226).wav
# a_(227).wav
# a_(228).wav
# a_(229).wav
# a_(23).wav
# a_(230).wav
# a_(231).wav
# a_(232).wav
# a_(233).wav
# a_(234).wav
# a_(235).wav
# a_(236).wav
# a_(237).wav
# a_(238).wav
# a_(239).wav
# a_(24).wav
# a_(240).wav
# a_(241).wav
# a_(242).wav
# a_(243).wav
# a_(244).wav
# a_(245).wav
# a_(246).wav
# a_(247).wav
# a_(248).wav
# a_(249).wav
# a_(25).wav
# a_(250).wav
# a_(251).wav
# a_(252).wav
# a_(253).wav
# a_(254).wav
# a_(255).wav
# a_(256).wav
# a_(257).wav
# a_(258).wav
# a_(259).wav
# a_(26).wav
# a_(260).wav
# a_(261).wav
# a_(262).wav
# a_(263).wav
# a_(264).wav
# a_(265).wav
# a_(266).wav
# a_(267).wav
# a_(268).wav
# a_(27).wav
# a_(28).wav
# a_(29).wav
# a_(3).wav
# a_(30).wav
# a_(31).wav
# a_(32).wav
# a_(33).wav
# a_(34).wav
# a_(35).wav
# a_(36).wav
# a_(37).wav
# a_(38).wav
# a_(39).wav
# a_(4).wav
# a_(40).wav
# a_(41).wav
# a_(42).wav
# a_(43).wav
# a_(44).wav
# a_(45).wav
# a_(46).wav
# a_(47).wav
# a_(48).wav
# a_(49).wav
# a_(5).wav
# a_(50).wav
# a_(51).wav
# a_(52).wav
# a_(53).wav
# a_(54).wav
# a_(55).wav
# a_(56).wav
# a_(57).wav
# a_(58).wav
# a_(59).wav
# a_(6).wav
# a_(60).wav
# a_(61).wav
# a_(62).wav
# a_(63).wav
# a_(64).wav
# a_(65).wav
# a_(66).wav
# a_(67).wav
# a_(68).wav
# a_(69).wav
# a_(7).wav
# a_(70).wav
# a_(71).wav
# a_(72).wav
# a_(73).wav
# a_(74).wav
# a_(75).wav
# a_(76).wav
# a_(77).wav
# a_(78).wav
# a_(79).wav
# a_(8).wav
# a_(80).wav
# a_(81).wav
# a_(82).wav
# a_(83).wav
# a_(84).wav
# a_(85).wav
# a_(86).wav
# a_(87).wav
# a_(88).wav
# a_(89).wav
# a_(9).wav
# a_(90).wav
# a_(91).wav
# a_(92).wav
# a_(93).wav
# a_(94).wav
# a_(95).wav
# a_(96).wav
# a_(97).wav
# a_(98).wav
# a_(99).wav
# e_(1).wav
# e_(10).wav
# e_(100).wav
# e_(101).wav
# e_(102).wav
# e_(103).wav
# e_(104).wav
# e_(105).wav
# e_(106).wav
# e_(107).wav
# e_(108).wav
# e_(109).wav
# e_(11).wav
# e_(110).wav
# e_(111).wav
# e_(112).wav
# e_(113).wav
# e_(114).wav
# e_(115).wav
# e_(116).wav
# e_(117).wav
# e_(118).wav
# e_(119).wav
# e_(12).wav
# e_(120).wav
# e_(121).wav
# e_(122).wav
# e_(123).wav
# e_(124).wav
# e_(125).wav
# e_(126).wav
# o_(107).wav
# o_(108).wav
# o_(109).wav
# o_(11).wav
# o_(110).wav
# o_(111).wav
# o_(112).wav
# o_(113).wav
# o_(114).wav
# o_(115).wav
# o_(116).wav
# o_(117).wav
# o_(118).wav
# o_(119).wav
# o_(12).wav
# o_(120).wav
# o_(121).wav
# o_(122).wav
# o_(123).wav
# o_(124).wav
# o_(125).wav
# o_(126).wav
# o_(127).wav
# o_(128).wav
# o_(129).wav
# o_(13).wav
# o_(130).wav
# o_(131).wav
# o_(132).wav
# o_(133).wav
# o_(134).wav
# o_(135).wav
# o_(136).wav
# o_(137).wav
# o_(138).wav
# o_(139).wav
# o_(14).wav
# o_(140).wav
# o_(141).wav
# o_(142).wav
# o_(143).wav
# o_(144).wav
# o_(145).wav
# o_(146).wav
# o_(147).wav
# o_(148).wav
# o_(149).wav
# o_(15).wav
# o_(150).wav
# o_(151).wav
# o_(152).wav
# o_(153).wav
# o_(154).wav
# o_(155).wav
# o_(156).wav
# o_(157).wav
# o_(158).wav
# o_(159).wav
# o_(16).wav
# o_(160).wav
# o_(161).wav
# o_(162).wav
# o_(163).wav
# o_(164).wav
# o_(165).wav
# o_(166).wav
# o_(167).wav
# o_(168).wav
# o_(169).wav
# o_(17).wav
# o_(170).wav
# o_(171).wav
# o_(172).wav
# o_(173).wav
# o_(174).wav
# o_(175).wav
# o_(176).wav
# o_(177).wav
# o_(178).wav
# o_(179).wav
# o_(18).wav
# o_(180).wav
# o_(181).wav
# o_(182).wav
# o_(183).wav
# o_(184).wav
# o_(185).wav
# o_(186).wav
# o_(187).wav
# o_(188).wav
# o_(189).wav
# o_(19).wav
# o_(190).wav
# o_(191).wav
# o_(192).wav
# o_(193).wav
# o_(194).wav
# o_(195).wav
# o_(196).wav
# o_(197).wav
# o_(198).wav
# o_(199).wav
# o_(2).wav
# o_(20).wav
# o_(200).wav
# o_(201).wav
# o_(202).wav
# o_(203).wav
# o_(204).wav
# o_(205).wav
# o_(206).wav
# o_(207).wav
# o_(208).wav
# o_(209).wav
# o_(21).wav
# o_(210).wav
# o_(211).wav
# o_(212).wav
# o_(213).wav
# o_(214).wav
# o_(215).wav
# o_(216).wav
# o_(217).wav
# o_(218).wav
# o_(219).wav
# o_(22).wav
# o_(220).wav
# o_(221).wav
# o_(222).wav
# o_(223).wav
# o_(224).wav
# o_(225).wav
# o_(226).wav
# o_(227).wav
# o_(228).wav
# o_(229).wav
# o_(23).wav
# o_(230).wav
# o_(231).wav
# o_(232).wav
# o_(233).wav
# o_(234).wav
# o_(235).wav
# o_(236).wav
# o_(237).wav
# o_(238).wav
# o_(239).wav
# o_(24).wav
# o_(240).wav
# o_(241).wav
# o_(242).wav
# o_(243).wav
# o_(244).wav
# o_(245).wav
# o_(246).wav
# o_(247).wav
# o_(248).wav
# o_(249).wav
# o_(25).wav
# o_(250).wav
# o_(251).wav
# o_(252).wav
# o_(253).wav
# o_(254).wav
# o_(255).wav
# o_(256).wav
# o_(257).wav
# o_(258).wav
# o_(259).wav
# o_(26).wav
# o_(260).wav
# o_(261).wav
# o_(262).wav
# o_(263).wav
# o_(264).wav
# o_(265).wav
# o_(266).wav
# o_(267).wav
# o_(268).wav
# o_(269).wav
# o_(27).wav
# o_(270).wav
# o_(271).wav
# o_(272).wav
# o_(28).wav
# o_(29).wav
# o_(3).wav
# o_(30).wav
# o_(31).wav
# o_(32).wav
# o_(33).wav
# o_(34).wav
# o_(35).wav
# o_(36).wav
# o_(37).wav
# o_(38).wav
# o_(39).wav
# o_(4).wav
# o_(40).wav
# o_(41).wav
# o_(42).wav
# o_(43).wav
# o_(44).wav
# o_(45).wav
# o_(46).wav
# o_(47).wav
# o_(48).wav
# o_(49).wav
# o_(5).wav
# o_(50).wav
# o_(51).wav
# o_(52).wav
# o_(53).wav
# o_(54).wav
# o_(55).wav
# o_(56).wav
# o_(57).wav
# o_(58).wav
# o_(59).wav
# o_(6).wav
# o_(60).wav
# o_(61).wav
# o_(62).wav
# o_(63).wav
# o_(64).wav
# o_(65).wav
# o_(66).wav
# o_(67).wav
# o_(68).wav
# o_(69).wav
# o_(7).wav
# o_(70).wav
# o_(71).wav
# o_(72).wav
# o_(73).wav
# o_(74).wav
# o_(75).wav
# o_(76).wav
# o_(77).wav
# o_(78).wav
# o_(79).wav
# o_(8).wav
# o_(80).wav
# o_(81).wav
# o_(82).wav
# o_(83).wav
# o_(84).wav
# o_(85).wav
# o_(86).wav
# o_(87).wav
# o_(88).wav
# o_(89).wav
# o_(9).wav
# o_(90).wav
# o_(91).wav
# o_(92).wav
# o_(93).wav
# o_(94).wav
# o_(95).wav
# o_(96).wav
# o_(97).wav
# o_(98).wav
# o_(99).wav
# u_(232).wav
# u_(233).wav
# u_(234).wav
# u_(235).wav
# u_(236).wav
# u_(237).wav
# u_(238).wav
# u_(239).wav
# u_(240).wav
# u_(241).wav
# u_(242).wav
# u_(243).wav
# u_(244).wav
# u_(245).wav
# u_(246).wav
# u_(247).wav
# u_(248).wav
# u_(249).wav
# u_(250).wav
# u_(251).wav
# u_(252).wav
# u_(253).wav
# u_(254).wav
# u_(255).wav
# u_(256).wav
# u_(257).wav
# u_(258).wav
# u_(259).wav
# u_(260).wav
# u_(261).wav
# u_(262).wav
# u_(263).wav
# u_(264).wav
# u_(265).wav
# u_(266).wav
# u_(267).wav
# u_(268).wav
# u_(269).wav
# u_(270).wav
# u_(271).wav
# u_(272).wav
# u_(273).wav
# u_(274).wav
# u_(275).wav
# u_(276).wav
# u_(277).wav
# u_(278).wav
# u_(279).wav
# u_(280).wav
# u_(281).wav
# u_(282).wav
# u_(283).wav
# u_(284).wav
# u_(285).wav
# u_(286).wav
# u_(287).wav
# u_(288).wav
# u_(289).wav
# u_(290).wav
# u_(291).wav
# u_(292).wav
# u_(293).wav
# u_(294).wav
# u_(295).wav
# u_(296).wav
# u_(297).wav
# u_(298).wav
# u_(299).wav
# u_(300).wav
# u_(301).wav
# u_(302).wav
# u_(303).wav
# u_(304).wav
# u_(305).wav
# u_(306).wav
# u_(307).wav
# u_(308).wav
# u_(309).wav
# u_(310).wav
# u_(311).wav
# u_(312).wav
# u_(313).wav
# u_(314).wav
# u_(315).wav
# u_(316).wav
# u_(317).wav
# u_(318).wav
# u_(319).wav
# %% [markdown]
# ## Creando csv con atributos de los audios

# %%
CSV_PATH = os.path.join(CURRENT_PATH, os.path.pardir, 'csv')

header = 'filename chroma_stft rmse spectral_centroid spectral_bandwidth rolloff zero_crossing_rate'

for i in range(1, 20): # origianlly is (1,21)
    header += f' mfcc{i}'

header += ' label'
header = header.split()

file = open(os.path.join(CSV_PATH, 'dataset.csv'), 'w', newline='')
with file:
    writer = csv.writer(file)
    writer.writerow(header)

vowels = 'a e i o u'.split()

for vowel in vowels:
    for filename in os.listdir(os.path.join(SAMPLES_PATH, f'{vowel}'))[1:]:
        vowel_sample = os.path.join(SAMPLES_PATH, f'{vowel}', filename) 
        if filename == 'desktop.ini': # omite desktop.ini
            break
        y, sr = librosa.load(vowel_sample, mono=True, duration=30)
        rms = librosa.feature.rms(y=y) # The latest librosa replaced rmse with rms, 
        # chroma_stft = librosa.feature.chroma_stft(y=y, sr=sr)
        spec_cent = librosa.feature.spectral_centroid(y=y, sr=sr)
        spec_bw = librosa.feature.spectral_bandwidth(y=y, sr=sr)
        rolloff = librosa.feature.spectral_rolloff(y=y, sr=sr)
        zcr = librosa.feature.zero_crossing_rate(y)
        mfcc = librosa.feature.mfcc(y=y, sr=sr)
        # to_append = f'{filename} {np.mean(chroma_stft)} {np.mean(rms)} {np.mean(spec_cent)} {np.mean(spec_bw)} {np.mean(rolloff)} {np.mean(zcr)}'
        to_append = f'{filename} {np.mean(rms)} {np.mean(spec_cent)} {np.mean(spec_bw)} {np.mean(rolloff)} {np.mean(zcr)}'    
        
        for e in mfcc:
            to_append += f' {np.mean(e)}'
        
        to_append += f' {vowel}'
        file = open(os.path.join(CSV_PATH, 'dataset.csv'), 'a', newline='')
        
        with file:
            writer = csv.writer(file)
            writer.writerow(to_append.split())

# %% [markdown]
# ## Dividiendo el conjunto de datos en train y test

# %%
data = pd.read_csv(os.path.join(CSV_PATH, 'dataset.csv'))
data.head() # Dropping unneccesary columns
# Out:
#       filename  chroma_stft         rmse  spectral_centroid  \
# 0    a_(1).wav     0.078709  1352.361637        1586.222325
# 1   a_(10).wav     0.070051  1338.283847        1612.799946
# 2  a_(100).wav     0.183272  1230.132660        1299.195610
# 3  a_(101).wav     0.164784  1118.158996        1174.958891
# 4  a_(102).wav     0.127276  1354.768330        1534.176402
#
#    spectral_bandwidth   rolloff  zero_crossing_rate       mfcc1      mfcc2  \
# 0         2417.909546  0.061951         -195.161057  155.052734 -32.641567
# 1         2347.771662  0.058579         -226.271652  156.350143 -21.872320
# 2         2052.114258  0.065283         -174.567352  165.541260 -52.337463
# 3         1484.252930  0.060955         -186.666275  182.520905 -34.975822
# 4         2566.734659  0.064758         -185.748901  162.806931 -37.369774
#
#        mfcc3  ...     mfcc11     mfcc12     mfcc13     mfcc14    mfcc15  \
# 0   9.159758  ...  -0.047796 -13.109210  -4.159160  -5.533259 -2.612540
# 1   4.680969  ...   3.293402  -7.723278  -6.780663  -7.603872 -3.309390
# 2 -10.619997  ...  15.753389  -3.234526 -29.682825  -6.204116  0.529301
# 3 -21.682854  ...  -1.141479   2.006813 -26.574198 -14.252640 -2.554953
# 4  11.770588  ...  -0.047263  -5.125896 -18.035034  -8.185450  4.124800
#
#       mfcc16    mfcc17    mfcc18    mfcc19  label
# 0  -6.622783 -3.217532 -5.889333 -0.514631      a
# 1  -8.553095 -2.232722 -5.898294 -2.178934      a
# 2  -4.536174  0.653478  0.554122  4.489969      a
# 3 -30.448599  3.288739  0.205309 -8.175979      a
# 4  -9.562122 -1.907890 -1.267814 -3.732115      a
#
# [5 rows x 27 columns]

# %%
data = data.drop(['filename'],axis=1)#Encoding the Labels
vowel = data.iloc[:, -1]
encoder = LabelEncoder()
y = encoder.fit_transform(vowel)#Scaling the Feature columns
scaler = StandardScaler()
X = scaler.fit_transform(np.array(data.iloc[:, :-1], dtype = float))#Dividing data into training and Testing set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
y
# Out:
# array([0, 0, 0, ..., 4, 4, 4])

# %% [markdown]
# ## Construyendo la ANN

# %%
model = Sequential()
model.add(layers.Dense(256, activation='relu', input_shape=(X_train.shape[1],)))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))
model.compile(optimizer='adam',   
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

classifier = model.fit(X_train,
                    y_train,
                    epochs=100,
                    batch_size=128)
# Out:
# Epoch 1/100
# 9/9 [==============================] - 1s 4ms/step - loss: 1.9836 - accuracy: 0.4357
# Epoch 2/100
# 9/9 [==============================] - 0s 4ms/step - loss: 1.1363 - accuracy: 0.7364
# Epoch 3/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6422 - accuracy: 0.8131
# Epoch 4/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4341 - accuracy: 0.8511
# Epoch 5/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3456 - accuracy: 0.8760
# Epoch 6/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2883 - accuracy: 0.8918
# Epoch 7/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2533 - accuracy: 0.9177
# Epoch 8/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2312 - accuracy: 0.9103
# Epoch 9/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2157 - accuracy: 0.9232
# Epoch 10/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2019 - accuracy: 0.9288
# Epoch 11/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1899 - accuracy: 0.9325
# Epoch 12/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1668 - accuracy: 0.9454
# Epoch 13/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1574 - accuracy: 0.9491
# Epoch 14/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1483 - accuracy: 0.9491
# Epoch 15/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1423 - accuracy: 0.9565
# Epoch 16/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1337 - accuracy: 0.9556
# Epoch 17/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1184 - accuracy: 0.9685
# Epoch 18/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1053 - accuracy: 0.9769
# Epoch 19/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1031 - accuracy: 0.9685
# Epoch 20/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1010 - accuracy: 0.9704
# Epoch 21/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0939 - accuracy: 0.9722
# Epoch 22/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0814 - accuracy: 0.9769
# Epoch 23/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0801 - accuracy: 0.9815
# Epoch 24/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0740 - accuracy: 0.9833
# Epoch 25/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0669 - accuracy: 0.9870
# Epoch 26/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0690 - accuracy: 0.9852
# Epoch 27/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0596 - accuracy: 0.9907
# Epoch 28/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0549 - accuracy: 0.9917
# Epoch 29/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0508 - accuracy: 0.9926
# Epoch 30/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0473 - accuracy: 0.9917
# Epoch 31/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0486 - accuracy: 0.9898
# Epoch 32/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0447 - accuracy: 0.9907
# Epoch 33/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0381 - accuracy: 0.9944
# Epoch 34/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0343 - accuracy: 0.9954
# Epoch 35/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0330 - accuracy: 0.9944
# Epoch 36/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0347 - accuracy: 0.9944
# Epoch 37/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0298 - accuracy: 0.9926
# Epoch 38/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0303 - accuracy: 0.9926
# Epoch 39/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0293 - accuracy: 0.9944
# Epoch 40/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0359 - accuracy: 0.9907
# Epoch 41/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0381 - accuracy: 0.9880
# Epoch 42/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0300 - accuracy: 0.9954
# Epoch 43/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0243 - accuracy: 0.9963
# Epoch 44/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0226 - accuracy: 0.9963
# Epoch 45/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0215 - accuracy: 0.9954
# Epoch 46/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0225 - accuracy: 0.9963
# Epoch 47/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0201 - accuracy: 0.9935
# Epoch 48/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0168 - accuracy: 0.9963
# Epoch 49/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0157 - accuracy: 0.9972
# Epoch 50/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0198 - accuracy: 0.9954
# Epoch 51/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0278 - accuracy: 0.9917
# Epoch 52/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0247 - accuracy: 0.9954
# Epoch 53/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0132 - accuracy: 0.9972
# Epoch 54/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0146 - accuracy: 0.9981
# Epoch 55/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0197 - accuracy: 0.9954
# Epoch 56/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0121 - accuracy: 0.9981
# Epoch 57/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0125 - accuracy: 0.9954
# Epoch 58/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0132 - accuracy: 0.9963
# Epoch 59/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0189 - accuracy: 0.9954
# Epoch 60/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0123 - accuracy: 0.9981
# Epoch 61/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0138 - accuracy: 0.9954
# Epoch 62/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0085 - accuracy: 0.9991
# Epoch 63/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0115 - accuracy: 0.9981
# Epoch 64/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0111 - accuracy: 0.9981
# Epoch 65/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0113 - accuracy: 0.9944
# Epoch 66/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0097 - accuracy: 0.9972
# Epoch 67/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0092 - accuracy: 0.9991
# Epoch 68/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0080 - accuracy: 0.9991
# Epoch 69/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0074 - accuracy: 0.9981
# Epoch 70/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0102 - accuracy: 0.9954
# Epoch 71/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0076 - accuracy: 0.9963
# Epoch 72/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 73/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0077 - accuracy: 0.9981
# Epoch 74/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0072 - accuracy: 0.9981
# Epoch 75/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0078 - accuracy: 0.9981
# Epoch 76/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0077 - accuracy: 0.9972
# Epoch 77/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0081 - accuracy: 0.9981
# Epoch 78/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0095 - accuracy: 0.9972
# Epoch 79/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0095 - accuracy: 0.9963
# Epoch 80/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0062 - accuracy: 0.9981
# Epoch 81/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0075 - accuracy: 0.9963
# Epoch 82/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0134 - accuracy: 0.9963
# Epoch 83/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0140 - accuracy: 0.9972
# Epoch 84/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0155 - accuracy: 0.9935
# Epoch 85/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0119 - accuracy: 0.9972
# Epoch 86/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0076 - accuracy: 0.9981
# Epoch 87/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0058 - accuracy: 0.9991
# Epoch 88/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 89/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0045 - accuracy: 0.9991
# Epoch 90/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0056 - accuracy: 0.9981
# Epoch 91/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0043 - accuracy: 0.9981
# Epoch 92/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0058 - accuracy: 0.9991
# Epoch 93/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0042 - accuracy: 0.9981
# Epoch 94/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0047 - accuracy: 0.9981
# Epoch 95/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0046 - accuracy: 0.9981
# Epoch 96/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0029 - accuracy: 0.9991
# Epoch 97/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 98/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0038 - accuracy: 0.9991
# Epoch 99/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 100/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0040 - accuracy: 0.9991

# %%
predict_x=model.predict(X_test[0:5]) 
classes_x=np.argmax(predict_x,axis=1)
pred_str = str(encoder.inverse_transform(classes_x))
test_str = encoder.inverse_transform(y_test[0:5])

print(f"la muestra corresponde a las vocales {test_str}, la predicción es {pred_str}")
# Out:
# la muestra corresponde a las vocales ['a' 'a' 'a' 'a' 'i'], la predicción es ['a' 'a' 'a' 'a' 'i']

# %%
model.evaluate(X_test, y_test)
# Out:
# 9/9 [==============================] - 0s 1ms/step - loss: 0.2019 - accuracy: 0.9557
# [0.20186373591423035, 0.955719530582428]

# %% [markdown]
# # Referencias
#
# [Sound Visualization](https://maelfabien.github.io/machinelearning/Speech10/#)
#
# [Vibration Analysis: FFT, PSD, and Spectrogram Basics](https://blog.endaq.com/vibration-analysis-fft-psd-and-spectrogram)
#
# [The Power Spectrum](https://mark-kramer.github.io/Case-Studies-Python/03.html)
#
# [Formate](https://es.wikipedia.org/wiki/Formante)
#
# [Las características acústicas de los elementos segmentales](http://liceu.uab.es/~joaquim/phonetics/fon_anal_acus/caract_acust.html): Acá hay una imagen de los espectrogramas de las vocales, en donde se identifican los formantes.
#
# [Audio Deep Learning Made Simple: Sound Classification, Step-by-Step](https://towardsdatascience.com/audio-deep-learning-made-simple-sound-classification-step-by-step-cebc936bbe5)
#
# [Introduction to Audio Classification](https://www.analyticsvidhya.com/blog/2021/06/introduction-to-audio-classification/)
#
# [Audio Data Analysis Using Deep Learning with Python (Part 1)](https://www.kdnuggets.com/2020/02/audio-data-analysis-deep-learning-python-part-1.html)
